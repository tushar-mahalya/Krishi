# %% [markdown]
# # 💪 Model Performance

# %%
# Importing important libraries 
import sys
import json
sys.path.append('/home/studio-lab-user/Krishi')

# Custom helper module/functions
from src.utils import plot_history
from src.utils import plot_loss_accuracy

# %%
# Loading model training information
with open('/home/studio-lab-user/Krishi/artifacts/model_info.json') as file:
    model_info_dict = json.load(file)

# %% [markdown]
# ### Apple Model Performance

# %%
plot_history(model_info_dict, 'Apple')
plot_loss_accuracy(model_info_dict, 'Apple')

# %% [markdown]
# ### Bell Pepper Model Performance

# %%
plot_history(model_info_dict, 'Bell Pepper')
plot_loss_accuracy(model_info_dict, 'Bell Pepper')

# %% [markdown]
# ### Cherry Model Performance

# %%
plot_history(model_info_dict, 'Cherry')
plot_loss_accuracy(model_info_dict, 'Cherry')

# %% [markdown]
# ### Corn (Maize) Model Performance

# %%
plot_history(model_info_dict, 'Corn (Maize)')
plot_loss_accuracy(model_info_dict, 'Corn (Maize)')

# %% [markdown]
# ### Grape Model Performance

# %%
plot_history(model_info_dict, 'Grape')
plot_loss_accuracy(model_info_dict, 'Grape')

# %% [markdown]
# ### Peach Model Performance

# %%
plot_history(model_info_dict, 'Peach')
plot_loss_accuracy(model_info_dict, 'Peach')

# %% [markdown]
# ### Potato Model Performance

# %%
plot_history(model_info_dict, 'Potato')
plot_loss_accuracy(model_info_dict, 'Potato')

# %% [markdown]
# ### Strawberry Model Performance

# %%
plot_history(model_info_dict, 'Strawberry')
plot_loss_accuracy(model_info_dict, 'Strawberry')

# %% [markdown]
# ### Tomato Model Performance

# %%
plot_history(model_info_dict, 'Tomato')
plot_loss_accuracy(model_info_dict, 'Tomato')
